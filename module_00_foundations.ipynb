# %% [markdown]
# # Notebook: Module 0 - Foundations

# %%
print("Hello, machine learning world!")
# Out:
# Hello, machine learning world!

# %% [markdown]
# # Variables and Data Types

# %%
name = "Learner"
age = 30
height = 5.9
is_enrolled = True
print(f"Name: {name}, Age: {age}, Height: {height}, Enrolled: {is_enrolled}")
# Out:
# Name: Learner, Age: 30, Height: 5.9, Enrolled: True

# %% [markdown]
# # Control Flow

# %%
if is_enrolled:
    print("Welcome to the ML course!")
# Out:
# Welcome to the ML course!

# %% [markdown]
# # Loops and Functions

# %%
def square(x):
    return x * x

for i in range(5):
    print(f"{i} squared is {square(i)}")
# Out:
# 0 squared is 0
# 1 squared is 1
# 2 squared is 4
# 3 squared is 9
# 4 squared is 16

# %% [markdown]
# # Lists and Dictionaries

# %%
languages = ["Python", "Ruby", "JavaScript"]
features = {"Python": "ML-friendly", "Ruby": "Elegant", "JavaScript": "Browser-native"}
print("Languages:", languages)
print("Python is", features["Python"])
# Out:
# Languages: ['Python', 'Ruby', 'JavaScript']
# Python is ML-friendly

# %% [markdown]
# ## Jupyter Notebook Tips
# - Press `Shift + Enter` to run a cell
# - Use `#` to write comments
# - Mix code and markdown for better documentation
