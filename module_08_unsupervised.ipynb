# %% [markdown]
# # Notebook: Module 8 - Unsupervised Learning

# %%
from sklearn.datasets import load_iris
from sklearn.cluster import KMeans
import pandas as pd
import altair as alt

iris = load_iris()
df = pd.DataFrame(iris.data, columns=iris.feature_names)
kmeans = KMeans(n_clusters=3, random_state=0).fit(iris.data)
df['cluster'] = kmeans.labels_

chart = alt.Chart(df).mark_circle().encode(
    x=iris.feature_names[0],
    y=iris.feature_names[1],
    color='cluster:N'
)
chart
# Out:
# alt.Chart(...)

# %% [markdown]
# # 🧠 Exercise:
# 1. Use `DBSCAN` or `AgglomerativeClustering`.
# 2. Visualize clusters using another pair of features.
